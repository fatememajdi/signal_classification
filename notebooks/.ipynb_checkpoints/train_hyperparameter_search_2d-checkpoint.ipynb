# %%
import sys
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle

# %%
# Add project root to path
sys.path.append('../src')

# %%
from train import random_search_hyperparameters_2d
from preprocessing import load_dataset

# %%
healthy_path = "../data/raw/Normal Condition"
faulty_path = "../data/raw/Looseness"
output_pkl_path = "../data/processed/signals_2d_df.pkl"

df = load_dataset(healthy_path, faulty_path, output_pkl_path)
X = np.stack(df['spectrogram'].values)[..., np.newaxis]
y = df['label'].values

X, y = shuffle(X, y, random_state=42)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

# %%
random_search_hyperparameters_2d(X_train, y_train, X_test, y_test)
# Out:
# 🔍 Running config 1/5: {'num_filters': 32, 'lr': 0.0001, 'epochs': 50, 'batch_size': 16}
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# ✅ Validation Accuracy: 92.50%
# 🔍 Running config 2/5: {'num_filters': 16, 'lr': 0.0001, 'epochs': 50, 'batch_size': 16}
# ✅ Validation Accuracy: 91.67%
# 🔍 Running config 3/5: {'num_filters': 16, 'lr': 0.0001, 'epochs': 60, 'batch_size': 16}
# ✅ Validation Accuracy: 94.17%
# 🔍 Running config 4/5: {'num_filters': 32, 'lr': 1e-05, 'epochs': 60, 'batch_size': 32}
# ✅ Validation Accuracy: 83.33%
# 🔍 Running config 5/5: {'num_filters': 16, 'lr': 0.0001, 'epochs': 60, 'batch_size': 32}
# ✅ Validation Accuracy: 93.33%
# ...
