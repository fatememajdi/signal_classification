# %%
import sys
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle

# %%
# Add project root to path
sys.path.append('../src')

# %%
from train import random_search_hyperparameters
from preprocessing import load_all_signals, normalize_signal

# %%
healthy_dir = "../data/raw/Normal Condition"
faulty_dir = "../data/raw/Looseness"
output_pkl_path = "../data/processed/signals_df.pkl"

df = load_all_signals(healthy_dir, faulty_dir, output_pkl_path)

# %%
df['processed_signal'] = df['signal'].apply(normalize_signal)

# %%
X = np.stack(df['processed_signal'].values)
y = df['label'].values
X, y = shuffle(X, y, random_state=42)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

# %%
random_search_hyperparameters(X_train, y_train, X_test, y_test)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/model_selection/_search.py:320: UserWarning: The total space of parameters 4 is smaller than n_iter=5. Running 4 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# [🔍] Running random config 1/5: {'num_filters': 32, 'max_pool': 5, 'lr': 0.0001, 'epochs': 80, 'batch_size': 32}
# Validation Accuracy: 85.00%
# [🔍] Running random config 2/5: {'num_filters': 32, 'max_pool': 5, 'lr': 1e-05, 'epochs': 80, 'batch_size': 32}
# Validation Accuracy: 50.00%
# [🔍] Running random config 3/5: {'num_filters': 32, 'max_pool': 5, 'lr': 0.0001, 'epochs': 90, 'batch_size': 32}
# Validation Accuracy: 85.00%
# [🔍] Running random config 4/5: {'num_filters': 32, 'max_pool': 5, 'lr': 1e-05, 'epochs': 90, 'batch_size': 32}
# Validation Accuracy: 50.00%
# ...
